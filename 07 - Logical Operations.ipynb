# %% [markdown]
# Python can use **Comparison operators** to compare two statement and provie an answer as True (1) or False (0).  Here are the symbols used by python to denote logical oporations betweeen values or variables
#
# ![image.png](attachment:image.png)

# %%
1>0
# Out:
# True

# %%
1<0
# Out:
# False

# %% [markdown]
# Python can also perform logical operations. The fundamental logical operators are **not**, **and**, and **or**

# %% [markdown]
# <div>
# <img src="attachment:9332fe66-0888-48d9-a6ca-801bf93adabf.png" width="300"/>
# </div>

# %% [markdown]
# <div>
# <img src="attachment:eba6c453-8993-44c4-9116-49f861b76e0d.png" width="300"/>
# </div>

# %% [markdown]
# <div>
# <img src="attachment:e40b46c4-74a6-426e-b606-7a7fc7b8d0af.png" width="300"/>
# </div>

# %%
(1>0), not(1 > 0)
# Out:
# (True, False)

# %%
(1<0), not(1 < 0)
# Out:
# (False, True)

# %%
(1>0), (2==3), (1>0) or (2==3)
# Out:
# (True, False, True)

# %%
(1>0), (2==3), (1>0) and (2==3)
# Out:
# (True, False, False)

# %%
(not (1>0)) or (2==3)
# Out:
# False

# %%
(5+3) > (3+5)
# Out:
# False

# %%
import math
import numpy as np

math.sin(math.pi/2) == np.sin(np.pi/2)
# Out:
# True

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sin(3.141592653589793) == math.cos((3.141592653589793/2))
# Out:
# False

# %%
math.sin(math.pi)
# Out:
# 1.2246467991473532e-16

# %%
math.cos(math.pi/2)
# Out:
# 6.123233995736766e-17

# %% [markdown]
# You can also work with True and False statements directly. For example

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or True, True or False, False or True, False or False
# Out:
# (True, True, True, False)

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False
